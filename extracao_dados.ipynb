# %%
import pandas as pd
import numpy as np
import re

# %%
df = pd.read_excel(r"C:\Users\lccam\OneDrive\Área de Trabalho\governanca\dash_gov_fea_dev\Planilha de Presença 2025.1.xlsx", sheet_name="Presença - Reuniões Semanais")

# %%
df.columns = df.columns.str.lower()

# %%
df = df.rename(columns={"membros ativos 2025.1":"membros_ativos","gênero":"genero","área administrativa":"area_administrativa","e-mail":"email","pontuação final":"pontuacao_final"})
df.columns = df.columns.str.replace("/", "_")

# %%
df["pontuacao_final"] = df["pontuacao_final"].astype(int)

# %%
df = df.loc[:,df.columns.notna()]

# %%
#for coluna in df.columns:
#    if coluna != "pontuacao_final":
#        df[coluna] = df[coluna].astype(str).str.replace("nan", "0")

# %%
df["score"] = pd.to_numeric(df["score"], errors="coerce")

# %%
df["score"] = round(df["score"],2)

# %%
# Levar em conta apenas as áreas que realizam reuniões semanais de forma recorrente

df["flag_considerar"] = df["area_administrativa"].apply(lambda x: 1 if x == "RH" or x == "MKT" else 0)

# %%
colunas_especificas = [col for col in df.columns if re.match(r"\d\d_\d\d", col) or col == "membros_ativos"]

# %%
df_auxiliar = df[colunas_especificas]

# %%
df_auxiliar
# Out:
#                      membros_ativos 02_02 09_02 16_02 23_02 02_03 09_03 16_03  \
# 0   Henrique Nogueira Pedro Lindoso   NaN   NaN   NaN   NaN   NaN   NaN   NaN
# 1              Amabile Guerra Nunes   NaN     P     P   NaN     P     P     P
# 2            Felippe Gomes Bertollo   NaN   NaN   NaN   NaN   NaN   NaN   NaN
# 3             Gabriel De Sousa Braz   NaN   NaN   NaN   NaN   NaN   NaN   NaN
# 4            Vitor Aratani Katayama   NaN   NaN   NaN   NaN   NaN   NaN   NaN
# 5                Julia Babam Toledo   NaN     P     P   NaN     P     P     P
# 6          Gabriel da Silva Navarro   NaN   NaN   NaN   NaN   NaN   NaN   NaN
# 7       Vinicius dos Santos Pereira   NaN     P     P   NaN     P    FJ     P
# 8            Julia Cerqueira Vieira   NaN   NaN   NaN   NaN   NaN   NaN   NaN
# 9   Rafael Derrico dos Santos Abreu   NaN   NaN   NaN   NaN   NaN   NaN   NaN
# 10          Ygor Ronnan Miguel Reis   NaN     P     P   NaN     P     P    FJ
# 11         Lucas dos Santos Camargo   NaN   NaN   NaN     P   NaN   NaN   NaN
# 12            Luisa Yumi Aoki Ribas     P     P     P    FJ   NaN   NaN   NaN
# 13              Igor Pires Ferreira   NaN   NaN   NaN   NaN   NaN   NaN   NaN
# 14                 Gabriel Finamore   NaN   NaN   NaN   NaN   NaN   NaN   NaN
# 15             Felipe da Silva Melo   NaN     P     P     P   NaN   NaN   NaN
# 16         Luane Miranda de Andrade     P     P     P     P   NaN   NaN   NaN
# 17          Lucas Tortelli de Moura   NaN     P     P   NaN    FJ     P     P
# 18      José Eduardo Santos Sarrico   NaN   NaN   NaN   NaN   NaN   NaN   NaN
# 19          Anna Yoshi Une Mesquita   NaN    FJ     P   NaN     F     P     F
# 20           Marcos Felipe da Silva   NaN   NaN   NaN   NaN   NaN   NaN   NaN
# 21         Jessica Sayuri Goya Higa   NaN   NaN     P   NaN     P     F     P
# 22               Lorenzo Cavalcante   NaN   NaN   NaN   NaN   NaN   NaN   NaN
# 23    Emmanuelita Stephene Emmanuel    FJ     P     P    FJ   NaN   NaN   NaN
# 24                       Caio Huang     F     P     F     P   NaN   NaN   NaN
# 25              Felipe Hideki Komi    NaN     P     P   NaN     F     F     P
# 26         Eduarda Sabino de Morais   NaN     P     P   NaN     P     P     P
# 27        Leonardo de Souza Teodoro   NaN   NaN   NaN   NaN   NaN   NaN   NaN
# 28                Maisa Lumi Sonoda   NaN   NaN   NaN   NaN   NaN   NaN   NaN
# 29          Thales Vieira Rodrigues   NaN   NaN   NaN   NaN   NaN   NaN   NaN
# 30            Alexandre Feitosa Gil   NaN   NaN     P   NaN     P     P     P
# 31               Luciana Wu Yongdan   NaN     P     P     P   NaN   NaN   NaN
# 32              Marcelo Fridschtein   NaN   NaN   NaN   NaN   NaN   NaN   NaN
# 33         Eduardo Ludgerio Barrado   NaN   NaN   NaN   NaN   NaN   NaN   NaN
# 34      Pedro Enrico Pumar de Brito   NaN     P     P    FJ   NaN   NaN   NaN
#
#     23_03  30_03  ...  20_04  27_04  04_05  11_05  18_05  25_05  01_06  08_06  \
# 0     NaN    NaN  ...    NaN    NaN    NaN    NaN    NaN    NaN    NaN    NaN
# 1     NaN    NaN  ...    NaN    NaN    NaN    NaN    NaN    NaN    NaN    NaN
# 2     NaN    NaN  ...    NaN    NaN    NaN    NaN    NaN    NaN    NaN    NaN
# 3     NaN    NaN  ...    NaN    NaN    NaN    NaN    NaN    NaN    NaN    NaN
# 4     NaN    NaN  ...    NaN    NaN    NaN    NaN    NaN    NaN    NaN    NaN
# 5     NaN    NaN  ...    NaN    NaN    NaN    NaN    NaN    NaN    NaN    NaN
# 6     NaN    NaN  ...    NaN    NaN    NaN    NaN    NaN    NaN    NaN    NaN
# 7     NaN    NaN  ...    NaN    NaN    NaN    NaN    NaN    NaN    NaN    NaN
# 8     NaN    NaN  ...    NaN    NaN    NaN    NaN    NaN    NaN    NaN    NaN
# 9     NaN    NaN  ...    NaN    NaN    NaN    NaN    NaN    NaN    NaN    NaN
# 10    NaN    NaN  ...    NaN    NaN    NaN    NaN    NaN    NaN    NaN    NaN
# 11    NaN    NaN  ...    NaN    NaN    NaN    NaN    NaN    NaN    NaN    NaN
# 12    NaN    NaN  ...    NaN    NaN    NaN    NaN    NaN    NaN    NaN    NaN
# 13    NaN    NaN  ...    NaN    NaN    NaN    NaN    NaN    NaN    NaN    NaN
# 14    NaN    NaN  ...    NaN    NaN    NaN    NaN    NaN    NaN    NaN    NaN
# 15    NaN    NaN  ...    NaN    NaN    NaN    NaN    NaN    NaN    NaN    NaN
# 16    NaN    NaN  ...    NaN    NaN    NaN    NaN    NaN    NaN    NaN    NaN
# 17    NaN    NaN  ...    NaN    NaN    NaN    NaN    NaN    NaN    NaN    NaN
# 18    NaN    NaN  ...    NaN    NaN    NaN    NaN    NaN    NaN    NaN    NaN
# 19    NaN    NaN  ...    NaN    NaN    NaN    NaN    NaN    NaN    NaN    NaN
# 20    NaN    NaN  ...    NaN    NaN    NaN    NaN    NaN    NaN    NaN    NaN
# 21    NaN    NaN  ...    NaN    NaN    NaN    NaN    NaN    NaN    NaN    NaN
# 22    NaN    NaN  ...    NaN    NaN    NaN    NaN    NaN    NaN    NaN    NaN
# 23    NaN    NaN  ...    NaN    NaN    NaN    NaN    NaN    NaN    NaN    NaN
# 24    NaN    NaN  ...    NaN    NaN    NaN    NaN    NaN    NaN    NaN    NaN
# 25    NaN    NaN  ...    NaN    NaN    NaN    NaN    NaN    NaN    NaN    NaN
# 26    NaN    NaN  ...    NaN    NaN    NaN    NaN    NaN    NaN    NaN    NaN
# 27    NaN    NaN  ...    NaN    NaN    NaN    NaN    NaN    NaN    NaN    NaN
# 28    NaN    NaN  ...    NaN    NaN    NaN    NaN    NaN    NaN    NaN    NaN
# 29    NaN    NaN  ...    NaN    NaN    NaN    NaN    NaN    NaN    NaN    NaN
# 30    NaN    NaN  ...    NaN    NaN    NaN    NaN    NaN    NaN    NaN    NaN
# 31    NaN    NaN  ...    NaN    NaN    NaN    NaN    NaN    NaN    NaN    NaN
# 32    NaN    NaN  ...    NaN    NaN    NaN    NaN    NaN    NaN    NaN    NaN
# 33    NaN    NaN  ...    NaN    NaN    NaN    NaN    NaN    NaN    NaN    NaN
# 34    NaN    NaN  ...    NaN    NaN    NaN    NaN    NaN    NaN    NaN    NaN
#
#     15_06  22_06
# 0     NaN    NaN
# 1     NaN    NaN
# 2     NaN    NaN
# 3     NaN    NaN
# 4     NaN    NaN
# 5     NaN    NaN
# 6     NaN    NaN
# 7     NaN    NaN
# 8     NaN    NaN
# 9     NaN    NaN
# 10    NaN    NaN
# 11    NaN    NaN
# 12    NaN    NaN
# 13    NaN    NaN
# 14    NaN    NaN
# 15    NaN    NaN
# 16    NaN    NaN
# 17    NaN    NaN
# 18    NaN    NaN
# 19    NaN    NaN
# 20    NaN    NaN
# 21    NaN    NaN
# 22    NaN    NaN
# 23    NaN    NaN
# 24    NaN    NaN
# 25    NaN    NaN
# 26    NaN    NaN
# 27    NaN    NaN
# 28    NaN    NaN
# 29    NaN    NaN
# 30    NaN    NaN
# 31    NaN    NaN
# 32    NaN    NaN
# 33    NaN    NaN
# 34    NaN    NaN
#
# [35 rows x 22 columns]

# %%
# Create a new column 'total_presencas' that counts occurrences of 'P' in date columns
df_auxiliar['total_p'] = df_auxiliar.apply(lambda row: row.str.count('P'), axis=1)
df_auxiliar['total_f'] = df_auxiliar.apply(lambda row: row.str.count('F'), axis=1)
df_auxiliar['total_fj'] = df_auxiliar.apply(lambda row: row.str.count('FJ'), axis=1)
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# ~\AppData\Local\Temp\ipykernel_43040\2500425038.py in ?()
#       1 # Create a new column 'total_presencas' that counts occurrences of 'P' in date columns
# ----> 2 df_auxiliar['total_p'] = df_auxiliar.apply(lambda row: row.str.count('P'), axis=1)
#       3 df_auxiliar['total_f'] = df_auxiliar.apply(lambda row: row.str.count('F'), axis=1)
#       4 df_auxiliar['total_fj'] = df_auxiliar.apply(lambda row: row.str.count('FJ'), axis=1)
#
# c:\Users\lccam\AppData\Local\Programs\Python\Python313\Lib\site-packages\pandas\core\frame.py in ?(self, key, value)
#    4297             self._setitem_frame(key, value)
#    4298         elif isinstance(key, (Series, np.ndarray, list, Index)):
#    4299             self._setitem_array(key, value)
#    4300         elif isinstance(value, DataFrame):
# -> 4301             self._set_item_frame_value(key, value)
#    4302         elif (
#    4303             is_list_like(value)
#    4304             and not self.columns.is_unique
#
# c:\Users\lccam\AppData\Local\Programs\Python\Python313\Lib\site-packages\pandas\core\frame.py in ?(self, key, value)
#    4455
#    4456             return self.isetitem(locs, value)
#    4457
#    4458         if len(value.columns) > 1:
# -> 4459             raise ValueError(
#    4460                 "Cannot set a DataFrame with multiple columns to the single "
#    4461                 f"column {key}"
#    4462             )
#
# ValueError: Cannot set a DataFrame with multiple columns to the single column total_p

# %%
df_final = pd.merge(df,df_auxiliar[["membros_ativos","total_p","total_f","total_fj"]], on="membros_ativos", how="left")

# %%
df_final.to_excel("teste.xlsx",index=False)

# %%
df = pd.read_excel(r"C:\Users\lccam\OneDrive\Área de Trabalho\governanca\dash_gov_fea_dev\Planilha de Presença 2025.1.xlsx", sheet_name="Presença - Outros Eventos")

# %%
df.to_excel("reuniões_semanais.xlsx", index=False)

# %%
df.columns = df.columns.str.lower()

# %%
df = df.rename(columns={"membros ativos 2025.1":"membros_ativos","gênero":"genero","área administrativa":"area_administrativa","e-mail":"email","pontuação final":"pontuacao_final"})
df.columns = df.columns.str.replace("/", "_")

# %%
df["pontuacao_final"] = df["pontuacao_final"].astype(int)

# %%
df = df.loc[:,df.columns.notna()]

# %%
for coluna in df.columns:
    if coluna != "pontuacao_final":
        df[coluna] = df[coluna].astype(str).str.replace("nan", "0")

# %%
df["score"] = pd.to_numeric(df["score"], errors="coerce")
df["score"] = round(df["score"],2)

# %%
# Levar em conta apenas as áreas que realizam reuniões semanais de forma recorrente

df["flag_considerar"] = df["area_administrativa"].apply(lambda x: 1 if x == "RH" or x == "MKT" else 0)

# %%
df.to_excel(r"Lista de Presença - Outros Eventos.xlsx", index=False)

# %%
import plotly.express as px
df = px.data.iris()
fig = px.parallel_coordinates(df, color="species_id", labels={"species_id": "Species",
                  "sepal_width": "Sepal Width", "sepal_length": "Sepal Length",
                  "petal_width": "Petal Width", "petal_length": "Petal Length", },
                    color_continuous_scale=px.colors.diverging.Tealrose, color_continuous_midpoint=2)
fig.show()
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[2], line 7
#       2 df = px.data.iris()
#       3 fig = px.parallel_coordinates(df, color="species_id", labels={"species_id": "Species",
#       4                   "sepal_width": "Sepal Width", "sepal_length": "Sepal Length",
#       5                   "petal_width": "Petal Width", "petal_length": "Petal Length", },
#       6                     color_continuous_scale=px.colors.diverging.Tealrose, color_continuous_midpoint=2)
# ----> 7 fig.show()
#
# File c:\Users\lccam\AppData\Local\Programs\Python\Python313\Lib\site-packages\plotly\basedatatypes.py:3414, in BaseFigure.show(self, *args, **kwargs)
#    3381 """
#    3382 Show a figure using either the default renderer(s) or the renderer(s)
#    3383 specified by the renderer argument
#    (...)
#    3410 None
#    3411 """
#    3412 import plotly.io as pio
# -> 3414 return pio.show(self, *args, **kwargs)
#
# File c:\Users\lccam\AppData\Local\Programs\Python\Python313\Lib\site-packages\plotly\io\_renderers.py:425, in show(fig, renderer, validate, **kwargs)
#     420     raise ValueError(
#     421         "Mime type rendering requires ipython but it is not installed"
#     422     )
#     424 if not nbformat or Version(nbformat.__version__) < Version("4.2.0"):
# --> 425     raise ValueError(
#     426         "Mime type rendering requires nbformat>=4.2.0 but it is not installed"
#     427     )
#     429 display_jupyter_version_warnings()
#     431 ipython_display.display(bundle, raw=True)
#
# ValueError: Mime type rendering requires nbformat>=4.2.0 but it is not installed
